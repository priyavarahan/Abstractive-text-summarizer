# %%
# !pip install datasets transformers rouge_score --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 28.9 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %%
# !pip install accelerate>=0.21.0 --quiet

# %%
# !pip install transformers[torch] --quiet

# %%
import accelerate
print(accelerate.__version__)
# Out:
# 0.29.3

# %%
from google.colab import drive
try:
    drive.mount('/content/drive')
except Exception as e:
    print(f"Error mounting Google Drive: {e}")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
train_data = pd.read_csv('/content/drive/MyDrive/cnn_dailymail/train.csv')
validation_data = pd.read_csv('/content/drive/MyDrive/cnn_dailymail/validation.csv')
test_data = pd.read_csv('/content/drive/MyDrive/cnn_dailymail/test.csv')

# %%
"""###Data Preprocessing"""

#dropping ID column
train_data = train_data.drop(['id'], axis=1)
validation_data = validation_data.drop(['id'], axis=1)
test_data = test_data.drop(['id'], axis=1)

print(train_data.shape, validation_data.shape, test_data.shape)

train_data.head()

validation_data.head()

test_data.head()

"""### BERT2BERT"""

# !pip install datasets
import datasets
from datasets import Dataset

# !pip install transformers==4.2.1
import transformers
from transformers import BertTokenizerFast

train_dataset = Dataset.from_pandas(train_data)
val_dataset = Dataset.from_pandas(validation_data)

tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")
tokenizer.bos_token = tokenizer.cls_token
tokenizer.eos_token = tokenizer.sep_token

batch_size=8
encoder_max_length=512
decoder_max_length=128

def process_data_to_model_inputs(batch):

  inputs = tokenizer(batch["article"], padding="max_length", truncation=True, max_length=encoder_max_length)
  outputs = tokenizer(batch["highlights"], padding="max_length", truncation=True, max_length=decoder_max_length)

  batch["input_ids"] = inputs.input_ids
  batch["attention_mask"] = inputs.attention_mask
  batch["decoder_input_ids"] = outputs.input_ids
  batch["decoder_attention_mask"] = outputs.attention_mask
  batch["labels"] = outputs.input_ids.copy()


  batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] for labels in batch["labels"]]

  return batch

train_dataset = train_dataset.select(range(15000))

train_dataset = train_dataset.map(
    process_data_to_model_inputs,
    batched=True,
    batch_size=batch_size,
    remove_columns=["article", "highlights"]
)
train_dataset.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)

val_dataset = val_dataset.select(range(200))

val_dataset = val_dataset.map(
    process_data_to_model_inputs,
    batched=True,
    batch_size=batch_size,
    remove_columns=["article", "highlights"]
)
val_dataset.set_format(
    type="torch", columns=["input_ids", "attention_mask", "decoder_input_ids", "decoder_attention_mask", "labels"],
)

val_dataset

from transformers import EncoderDecoderModel

bert2bert = EncoderDecoderModel.from_encoder_decoder_pretrained("bert-base-uncased", "bert-base-uncased")

bert2bert.config.decoder_start_token_id = tokenizer.bos_token_id
bert2bert.config.eos_token_id = tokenizer.eos_token_id
bert2bert.config.pad_token_id = tokenizer.pad_token_id

bert2bert.config.vocab_size = bert2bert.config.decoder.vocab_size
bert2bert.config.max_length = 142
bert2bert.config.min_length = 56
bert2bert.config.no_repeat_ngram_size = 3
bert2bert.config.early_stopping = True
bert2bert.config.length_penalty = 2.0
bert2bert.config.num_beams = 4

from transformers import Seq2SeqTrainingArguments, Seq2SeqTrainer

# !pip install rouge_score
# Out:
# (287113, 2) (13368, 2) (11490, 2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Collecting transformers==4.2.1
#   Downloading transformers-4.2.1-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.2.1) (3.13.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from transformers==4.2.1) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from transformers==4.2.1) (24.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.2.1) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.2.1) (2.31.0)
# Collecting sacremoses (from transformers==4.2.1)
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 11.4 MB/s eta 0:00:00
# Collecting tokenizers==0.9.4 (from transformers==4.2.1)
#   Downloading tokenizers-0.9.4.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 kB 14.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.2.1) (4.66.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.2.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.2.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.2.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.2.1) (2024.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.2.1) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from sacremoses->transformers==4.2.1) (1.4.0)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: Could not build wheels for tokenizers, which is required to install pyproject.toml-based projects
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Map:   0%|          | 0/15000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.0.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.0.crossattention.output.dense.bias', 'bert.encoder.layer.0.crossattention.output.dense.weight', 'bert.encoder.layer.0.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.0.crossattention.self.value.bias', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.1.crossattention.output.dense.weight', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.self.key.weight', 'bert.encoder.layer.1.crossattention.self.query.bias', 'bert.encoder.layer.1.crossattention.self.query.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.self.value.weight', 'bert.encoder.layer.10.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.10.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.10.crossattention.output.dense.bias', 'bert.encoder.layer.10.crossattention.output.dense.weight', 'bert.encoder.layer.10.crossattention.self.key.bias', 'bert.encoder.layer.10.crossattention.self.key.weight', 'bert.encoder.layer.10.crossattention.self.query.bias', 'bert.encoder.layer.10.crossattention.self.query.weight', 'bert.encoder.layer.10.crossattention.self.value.bias', 'bert.encoder.layer.10.crossattention.self.value.weight', 'bert.encoder.layer.11.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.11.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.11.crossattention.output.dense.bias', 'bert.encoder.layer.11.crossattention.output.dense.weight', 'bert.encoder.layer.11.crossattention.self.key.bias', 'bert.encoder.layer.11.crossattention.self.key.weight', 'bert.encoder.layer.11.crossattention.self.query.bias', 'bert.encoder.layer.11.crossattention.self.query.weight', 'bert.encoder.layer.11.crossattention.self.value.bias', 'bert.encoder.layer.11.crossattention.self.value.weight', 'bert.encoder.layer.2.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.2.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.2.crossattention.output.dense.bias', 'bert.encoder.layer.2.crossattention.output.dense.weight', 'bert.encoder.layer.2.crossattention.self.key.bias', 'bert.encoder.layer.2.crossattention.self.key.weight', 'bert.encoder.layer.2.crossattention.self.query.bias', 'bert.encoder.layer.2.crossattention.self.query.weight', 'bert.encoder.layer.2.crossattention.self.value.bias', 'bert.encoder.layer.2.crossattention.self.value.weight', 'bert.encoder.layer.3.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.3.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.3.crossattention.output.dense.bias', 'bert.encoder.layer.3.crossattention.output.dense.weight', 'bert.encoder.layer.3.crossattention.self.key.bias', 'bert.encoder.layer.3.crossattention.self.key.weight', 'bert.encoder.layer.3.crossattention.self.query.bias', 'bert.encoder.layer.3.crossattention.self.query.weight', 'bert.encoder.layer.3.crossattention.self.value.bias', 'bert.encoder.layer.3.crossattention.self.value.weight', 'bert.encoder.layer.4.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.4.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.4.crossattention.output.dense.bias', 'bert.encoder.layer.4.crossattention.output.dense.weight', 'bert.encoder.layer.4.crossattention.self.key.bias', 'bert.encoder.layer.4.crossattention.self.key.weight', 'bert.encoder.layer.4.crossattention.self.query.bias', 'bert.encoder.lay ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.25.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.2)

# %%
"""### FINE-TUNING"""

rouge = datasets.load_metric("rouge")

def compute_metrics(pred):
    labels_ids = pred.label_ids
    pred_ids = pred.predictions


    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    labels_ids[labels_ids == -100] = tokenizer.pad_token_id
    label_str = tokenizer.batch_decode(labels_ids, skip_special_tokens=True)

    rouge_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge2"])["rouge2"].mid

    return {
        "rouge2_precision": round(rouge_output.precision, 4),
        "rouge2_recall": round(rouge_output.recall, 4),
        "rouge2_fmeasure": round(rouge_output.fmeasure, 4),
    }

training_args = Seq2SeqTrainingArguments(
    output_dir="./",
    evaluation_strategy="steps",
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    predict_with_generate=True,
    overwrite_output_dir=True,
    save_total_limit=3,

)

trainer = Seq2SeqTrainer(
    model=bert2bert,
    tokenizer=tokenizer,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
)
trainer.train()
# Out:
# <ipython-input-8-526846fbc168>:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = datasets.load_metric("rouge")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.17k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
#     <div>
#
#       <progress value='5625' max='5625' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5625/5625 2:31:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge2 Precision</th>
#       <th>Rouge2 Recall</th>
#       <th>Rouge2 Fmeasure</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.057900</td>
#       <td>0.000125</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.000400</td>
#       <td>0.000045</td>
#       <td>0.000000</td>
#       <td>0.000100</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.001000</td>
#       <td>0.000037</td>
#       <td>0.000000</td>
#       <td>0.000100</td>
#       <td>0.000100</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.000700</td>
#       <td>0.000044</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.000100</td>
#       <td>0.000056</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.000100</td>
#       <td>0.000023</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.000300</td>
#       <td>0.000022</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.000100</td>
#       <td>0.000013</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.000000</td>
#       <td>0.000011</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.000000</td>
#       <td>0.000010</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.000000</td>
#       <td>0.000009</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1256: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# Some non-default generation parameters are set in the model config. These should go into a GenerationConfig file (https://huggingface.co/docs/transformers/generation_strategies#save-a-custom-decoding-strategy-with-your-model) instead. This warning will be raised to an exception in v4.41.
# Non-default generation parameters: {'max_length': 142, 'min_length': 56, 'early_stopping': True, 'num_beams': 4, 'length_penalty': 2.0, 'no_repeat_ngram_size': 3}
# /usr/local/lib/python3.10/dist-packages/transformers/models/encoder_decoder/modeling_encoder_decoder.py:643: FutureWarning: Version v4.12.0 introduces a better way to train encoder-decoder models by computing the loss inside the encoder-decoder framework rather than in the decoder itself. You may observe training discrepancies if fine-tuning a model trained with versions anterior to 4.12.0. The decoder_input_ids are now created based on the labels, no need to pass them yourself anymore.
#   warnings.warn(DEPRECATION_WARNING, FutureWarning)
# TrainOutput(global_step=5625, training_loss=0.005389767155134016, metrics={'train_runtime': 9079.2963, 'train_samples_per_second': 4.956, 'train_steps_per_second': 0.62, 'total_flos': 2.76054345216e+16, 'train_loss': 0.005389767155134016, 'epoch': 3.0})

# %%
"""###TESTING"""

# !ls

dummy_bert2bert = EncoderDecoderModel.from_pretrained("./checkpoint-5500")

import datasets
from transformers import BertTokenizer, EncoderDecoderModel

tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = EncoderDecoderModel.from_pretrained("./checkpoint-5500")
model.to("cuda")

test_dataset = Dataset.from_pandas(test_data)

test_dataset = test_dataset.select(range(200))

batch_size = 8

def generate_summary(batch):

    inputs = tokenizer(batch["article"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")
    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = model.generate(input_ids, attention_mask=attention_mask)


    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred"] = output_str

    return batch

results = test_dataset.map(generate_summary, batched=True, batch_size=batch_size, remove_columns=["article"])

pred_str = results["pred"]
label_str = results["highlights"]

rougeL_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rougeL"])["rougeL"].mid
rouge1_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge1"])["rouge1"].mid
rouge2_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge2"])["rouge2"].mid

print(rougeL_output)
print(rouge1_output)
print(rouge2_output)

results[1]

pred_str

test_dataset['article'][1]
# Out:
# '=0.21.0'   checkpoint-4500   checkpoint-5000   checkpoint-5500   drive   runs	 sample_data
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Score(precision=0.0296627136077912, recall=0.02200184723525876, fmeasure=0.01497359312398335)
# Score(precision=0.030836203214894622, recall=0.023598556926424097, fmeasure=0.016039858509563514)
# Score(precision=0.0, recall=0.0, fmeasure=0.0)
# "A drunk teenage boy had to be rescued by security after jumping into a lions' enclosure at a zoo in western India. Rahul Kumar, 17, clambered over the enclosure fence at the\xa0Kamla Nehru Zoological Park in Ahmedabad, and began running towards the animals, shouting he would 'kill them'. Mr Kumar explained afterwards that he was drunk and 'thought I'd stand a good chance' against the predators. Next level drunk: Intoxicated Rahul Kumar, 17, climbed into the lions' enclosure at a zoo in Ahmedabad and began running towards the animals shouting 'Today I kill a lion!' Mr Kumar had been sitting near the enclosure when he suddenly made a dash for the lions, surprising zoo security. The intoxicated teenager ran towards the lions, shouting: 'Today I kill a lion or a lion kills me!' A zoo spokesman said: 'Guards had earlier spotted him close to the enclosure but had no idea he was planing to enter it. 'Fortunately, there are eight moats to cross before getting to where the lions usually are and he fell into the second one, allowing guards to catch up with him and take him out. 'We then handed him over to the police.' Brave fool: Fortunately, Mr Kumar  fell into a moat as he ran towards the lions and could be rescued by zoo security staff before reaching the animals (stock image) Kumar later explained: 'I don't really know why I did it. 'I was drunk and thought I'd stand a good chance.' A police spokesman said: 'He has been cautioned and will be sent for psychiatric evaluation. 'Fortunately for him, the lions were asleep and the zoo guards acted quickly enough to prevent a tragedy similar to that in Delhi.' Last year a 20-year-old man was mauled to death by a tiger in the Indian capital after climbing into its enclosure at the city zoo."

# %%
"""### TESTING ON FINE-TUNED MODEL FROM HUGGING FACE"""

import datasets
from transformers import BertTokenizer, EncoderDecoderModel

model = EncoderDecoderModel.from_pretrained("patrickvonplaten/bert2bert_cnn_daily_mail").to("cuda")
tokenizer = BertTokenizer.from_pretrained("patrickvonplaten/bert2bert_cnn_daily_mail")

test_dataset = Dataset.from_pandas(test_data)

test_dataset = test_dataset.select(range(200))

batch_size = 8

def generate_summary(batch):

    inputs = tokenizer(batch["article"], padding="max_length", truncation=True, max_length=512, return_tensors="pt")
    input_ids = inputs.input_ids.to("cuda")
    attention_mask = inputs.attention_mask.to("cuda")

    outputs = model.generate(input_ids, attention_mask=attention_mask)


    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    batch["pred"] = output_str

    return batch

results = test_dataset.map(generate_summary, batched=True, batch_size=batch_size, remove_columns=["article"])

pred_str = results["pred"]
label_str = results["highlights"]

rougeL_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rougeL"])["rougeL"].mid
rouge1_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge1"])["rouge1"].mid
rouge2_output = rouge.compute(predictions=pred_str, references=label_str, rouge_types=["rouge2"])["rouge2"].mid

print(rougeL_output)
print(rouge1_output)
print(rouge2_output)

results[1]

test_dataset['article'][1]

pred_str
# Out:
# config.json:   0%|          | 0.00/3.66k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# Score(precision=0.2589453691579804, recall=0.2961255947705103, fmeasure=0.2696917098397658)
# Score(precision=0.38658994430131555, recall=0.43820404831275395, fmeasure=0.4011642807550139)
# Score(precision=0.17384853191324717, recall=0.1934675016936152, fmeasure=0.17861216601906998)
# ["the government is happy to set standards for animals flying on planes. but the government doesn't stipulate a minimum amount of space for humans. many economy seats on united airlines have 30 inches of room. some airlines offer as little as 28 inches, while some airlines have just 28 inches.",
#  "rahul kumar, 17, clambered over enclosure fence at kamla nehru zoological park in western india. he began running towards the lions, shouting he would'kill them'before jumping into the enclosure. mr kumar said he was drunk and'thought i'd stand a good chance'against predators.",
#  "dougie freedman is set to sign a new deal at nottingham forest. freedman has impressed at the city ground since replacing stuart pearce in february. the club's owners are pleased with freedman's job at the club. click here for all the latest transfer news with our live updates.",
#  "liverpool were linked with a move for the 25 - year - old. neto is also wanted by psg and psg in spain. the brazilian's agent has revealed no decision on his future has been made yet. read : neto will have his pick of top european clubs when the transfer window opens.",
#  "prasanna ‘ nick ’ arulchelvam, 34, died when he fell from a van in watford. customer reported hearing a'nasty crunch'as the vehicle sped off. he was jailed for 11 years after admitting manslaughter of mr prascoll.",
#  'the dramatic sunsets were the result of wildfires in parts of siberia. the fires were started by farmers burning grass in their fields. the blazes have destroyed dozens of villages in the region, cnn affiliate komo - tv says. the fire is believed to have spread out of control because of strong winds.',
#  'researchers believe the camel may have been left in the town of tulln for trading after the siege of vienna in 1677. genetic analysis of the animal show it was a bactrian - dromedary hybrid - a breed popular in the ottoman army at the time of the siege. the cross - breed camel had been most likely used as a riding and transport animal by the ottoman empire.',
#  'ben affleck asked producers to remove any reference to his great - great grandfather benjamin cole. the show\'s producer, henry louis gates jr., has publicly denied that he made his decision about the content of the program. he said he did not want the show to include a " guy who owned slaves "',
#  'ermias ghermay, 34, is thought to have made £72million with his accomplice mered medhanie, also known as the general. the pair are among several traffickers wanted in connection with a major human smuggling ring. medhanies are wanted on an arrest warrant for an october 2013 capsizing off lampedusa.',
#  'the 26 - year - old was spotted at the bahrain grand prix this morning. she was in the gulf state, ruled by a controversial king whose regime has been accused of repressing pro - democracy activists with her long - term boyfriend dave clark, according to an onlooker. princesses beatrice and eugenie were seen chatting animatedly to king carlos.',
#  "lois lerner won't be charged with a crime for defying a congressional subpoena and refusing to answer questions. the u. s. attorney for the district of columbia told house speaker john boehner in a 2013 hearing that lerner could wrap herself in the fifth amendment. lerner's letter was addressed to the house speaker, who was in jerusalem visiting with israeli prime minister benjamin netanyahu.'i'll tell the truth. unless i'm taking the fifth step,'she said.",
#  'isis is a problem that is " off the charts historically historically, " brett mcgurk says. he says the u. s. and its allies face " unchartered territory " in the fight against isis. the united states has stepped up efforts to involve sunni tribes to fight isis.',
#  "david cameron has been secretly using hair dye to turn back the years. ukip leader said he was'jealous'of how the tory leader has reversed the process while in downing street. mr cameron has previously been accused of visiting stylists and trichologists to keep his hair looking youthful.",
#  'bomb expert david hyche, now a special agent at the bureau of alcohol, has passed on the idea to the alabama institute for deaf and blind. a transmitter is placed inside plastic eggs that let off a high - pitched beeping sound. the device was developed nine years ago when his daughter turned blind.',
#  'jamyra gallmon, 21, has been charged with first - degree murder while armed for allegedly killing david messerschmitt, 30, on february 9 in washington, d. c. the woman admitted to police that she set up the lawyer using a masculine - sounding email address and went to the donovan hotel with the intention of robbing him. he was found dead in his hotel room with multiple stab wounds to the back, groin and abdomen along with one wound which pierced his heart and abdomen.',
#  'victims of yorkshire ripper peter sutcliffe are furious at plans to move him to a low - security priory unit set in berkshire woodland. but families of victims of the savage killings are furious about the move, it has been claimed. a report is being compiled which will be heard next month at a prison tribunal which will rule if the move goes ahead.',
#  "isis has announced plans to open a school in isis'de facto capital raqqa. details of the first nursing school to be opened in isis - held territory. the nhs does not have the same level of checks, despite legislation being passed last month making it legal for nurses to work within the territory.",
#  'jack nicklaus recorded his first hole - in - one at the masters on wednesday. kevin streelman had earlier holed out with an eight iron from 123 yards on the fourth. the 75 - year - old caddie ethan couch has a benign but inoperable brain tumour. nicklaus had earlier played in the masters par - three contest at augusta national.',
#  'former qpr chief gianni paladini has registered as a director of bradford city. the italian has been searching for a way back into football since leaving loftus road in 2011. he has attempted to buy birmingham city from carson yeung in a bid to buy the club. he is registered as the sole director of a new bradford city holding company.',
#  "lee tomlin and patrick bamford both scored in middlesbrough's 2 - 0 win at home to rotherham on saturday. the result leaves boro stay fourth in the sky bet championship table. the top three sides are all winning in the championship, while boro remain fourth. middlesbrough have now won their 14th home game of the season.",
#  "james may, 52, ordered a ferrari 458 speciale in bright orange. but clarkson punched producer oisin tymon in a rage over a hot meal. the'draft version'of the contract was sitting on his desk'with dignity'may admits ordering ferrari is a'strange thing for an unemployed person to do'but insists he will not return to top gear.",
#  "steven finn was overlooked for the west indies tour. the 26 - year - old says he's'had my trials and tribulations over the last 12 months'finn has played only one championship game for middlesex this season. england's fast bowling stocks are starting to worry selectors.",
#  "tom lineham scored two interception tries in an eye - catching hat - trick. jamie shaul went over late on to make sure of the two competition points for hull. kevin brown and patrick ah van couldn't prevent a second hull try. the 22 - year - old scored a treble in a loss to castleford last month.",
#  'both federal government regulations and the american heart association have for decades warned that excess salt contributes to the deaths of tens of thousands of americans each year. in february the dietary guidelines advisory committee recommended keeping the larger limit, although it withdrew support for the stricter limit for african americans and people over 50.',
#  'an fbi informant met the men after infiltrating a branch of the kkk. thomas jordan driver, 25, and charles thomas newcomb, 42, are facing up to 30 years in jail if convicted of conspiracy to commit murder. the fbi staged a fake homicide scene with the former inmate.',
#  "rafael benitez has been linked with a move to sampdoria. the spaniard is being lined up to replace sinisa mihajlovic at napoli. the former milanese is currently on a season - long contract with the serie a side. benitezo says he would rather keep hold of the serbian's mihojlovic.",
#  "lord prescott says prince of wales has'a lot of time for charles'the former deputy prime minister said he should'right to write as many damn letters as he likes'lord prescott said prince charles has'an awful lot to offer this country'the prince wrote a letter to a meeting of regional development agency leaders in 1999.",
#  'zimbabwe have agreed to travel for a short one - day international series next month. no tourists have played in pakistan because of security fears. zimbabwe are set to host test - playing opposition in their home country for the first time in more than six years. zimbabwe have reportedly agreed to play against pakistan in the past month.',
#  'the highly usual situation was no coincidence, but rather a clever marketing ploy dreamed up by retailer lord & taylor to promote its edgy new design lab collection. the $ 88 paisley asymmetrical dress sold out almost immediately and created an online buzz for the range. the company partnered with 50 of the most influential bloggers and got each to post a photo of them wearing the same dress.',
#  'danny willett shouted a verbal blast at the official, who had been in his line - of - sight. the englishman was still visibly angry as he left the green after salvaging a one - under 71. the 27 - year - old englishman is a two - time european tour winner. willett said his ire had been raised because the official was in line to play his shot.',
#  "tinder will now display the last 34 pictures of a person's instagram feed. the firm has updated its profile as part of the instagram integration. tinder also said it has improved its'mutual friends'feature. it also said the app would not let other users know it was part of a dating profile.",
#  'nathaniel clyne has impressed for manchester united this season. the right back has been linked with a move away from the south coast. ronald koeman has admitted it may be hard to keep clyne at the club this summer. click here for all the latest manchester united news.',
#  "mike heatlie, 42, launched the attack on fiona mccartney, 43, outside a nightclub in edinburgh. he claims she did not give him a cigarette and was left unconscious in a pool of blood. heatlie was once voted as one of the city's most eligible bachelors. but ms mccartney is now facing a £7, 000 dental bill and a dental bill.",
#  "robin van persie snr posted the video on his instagram account. the seven - year - old has trained with manchester united and starred in bt sport adverts. the dutch striker has 14 months left on his £250, 000 - a - week contract. louis van gaal's side will reportedly offer him £5million to leave old trafford.",
#  "rita, 24, has taken the brand's classics and put her own bold spin on them. femail caught up with the star to find out her influences and plans for the future. she said :'the dragon print is all about my love of travel and soaking up different cultures '",
#  "the 1961 ferrari 250 gt swb california spider is widely regarded by many as the most beautiful convertible ever made. it was used as the car for the 1986 teen comedy ferris bueller's day off. in one of the film world's best - known scenes, the beloved ferrari crashes into the ravine below. it will be sold next month at rm sotheby's auction in villa erba, italy, and has a guide price of £8 million.",
#  'automated computer program was designed as an online shopping system. it would spend up to $ 100 each week buying an item for sale on the deep web. the robot would then have its purchase mailed to a group of artists who then put the items in an exhibition in st gallen, switzerland. police seized the drugs, the computer and the rest of the items they had bought.',
#  "the sum is almost five times the prime minister's £142, 500 pay packet. a further 11 dentists were paid between £400, 000 and £500, 000. more than 1, 600 pocketed £100, 000 - a - year, according to the daily mail.",
#  "institute for fiscal studies analysed the policies of all main parties. institute said they are'predicated on substantial and almost entirely unspecified spending cuts and tax increases'tories accused of giving'no detail'about their deficit reduction plan. labour has left door open to borrowing an extra £26billion - a - year.",
#  "marathon season is in full swing with london marathon set to take place on sunday. trainers lucy waterlow tested out £130 adidas trainers against aldi's budget £19. 99 pair. the trainers are important to prevent injuries and ensure you have a comfortable and enjoyable experience. trainers are available for the budget price of £130.",
#  'nathan brown, 19, was working with his father david when he was electrocuted. he apparently touched a set of exposed electrical bars powering a crane. the shock caused him to fall 12ft head first onto the roof of a toilet block below. he was airlifted to hospital but later died of his injuries. inquest heard nathan was trained to become an electrician.',
#  'greg dyke must find £30million to fund his masterplan. fa chairman has identified non - league national team as an area of potential saving. england won 6 - 1 in bermuda in june 2013, and won 1 - 0 in jordan in march last year. former leicester winger steve guppy won one cap for scotland.',
#  "isis fighter jannahtain tweeted pictures of burger king, pringles and mojitos. he said :'that moment when a bro your helping cross the border into syria asks you if you need anything from turkey. jihad2015'isis fighter posted picture on his social media page showing several packs of pringle. one of his friends allegedly brought in a bag full of five cheeseburgers.",
#  'the pound fell to near 1. 46 against the us dollar, its lowest level since june 2010. experts warn of the impact on the economy of a badly hung parliament. labour and ed miliband both facing the prospect of having to rely on smaller parties to form a government.',
#  "justine jones was left covered in huge sores and in agony after opening bottle. mother - of - two had bought the bottle for granddaughter abi's 18th birthday. but despite the bottle being sealed and showing no evidence of being tampered with, the family were shocked when they found it contained clear liquid which smelt of bleach. the accountant, from shropshire, suffers from rare condition pemphigus, which means her immune system is extremely sensitive to certain chemicals.",
#  "a total of 215, 462 licences exist in new south wales compared to the 177, 675 owned in 2010. tamworth, 403km north of sydney, was revealed to have the most number of firearm licences - with bathurst, 200km west of sydney. the firearm registry's regulations suggest it's not easy to acquire a licence.",
#  'west ham are closing in on a deal for jamaican starlet deshane beckford. hammers have revealed season tickets at the olympic stadium will cost as little as £289. the hammers will have the cheapest pricing strategy in the barclays premier league in a bid to fill the 54, 000 capacity stadium when they make the switch.',
#  "more than 37 tons of fish have been collected, according to rio's waste management company, but there is still an overwhelming stench coming from the lake. over the past week, thousands of the silver fish have died and have been scooped out of the water by authorities and biologists have argued about the cause.",
#  "sbs has sacked its football reporter scott mcintyre over his'inappropriate and disrespectful'tweets. mcintyre accused the diggers of committing war crimes which included'widespread rape and theft'mcintyre referred to the anzac's landing on the gallipoli peninsula in turkey as an'imperialist invasion'mcintyre has more than 30, 000 twitter followers.",
#  "ruanne dellal says her husband jack was worth at least £400million when he died. the former beauty queen left his entire estate to wife ruanne, 61, but she is now suing six of her husband's children. her late husband, known as'black jack ', was a regular at casinos in mayfair and monaco. he died in october 2012, aged 89, leaving his entire fortune to his second wife.",
#  "nicholas pence, 25, and his father david, 56, were shot dead'execution - style'at their home in metairie, louisiana on wednesday night. police believe it was a botched armed burglary. david's wife, nicholas, had been in a bedroom when she heard gun shots. nicholas was found lying on the floor of their'man cave'in their garage. friends of nicholas have set up a fundraising page to support his family.",
#  "turia pitt, 18 months old, suffered burns to 64 per cent of her body during a september 2011 ultramarathon. turia's recovery is a case - in - point, and she believes australians take their medical system for granted. the australian charity, interplast, is raising funds for more volunteer medicos to head overseas. seng seng, who ran a half - marathon and beat the time she ran before the 2011 kimberley blaze, was seared by boiling water.",
#  'lucas leiva and alex song could leave manchester city in the summer. roberto mancini has been linked with a move away from the etihad. manchester city are keen on the manchester city duo he worked with while he was at west ham united. click here for all the latest transfer news with our live updates.',
#  "karen buckley vanished after night out in glasgow at the weekend. her body was found on a farm north of glasgow on friday. a man, believed to be 21 - year - old alexander pacteau, has been arrested in connection with miss buckley's death. he has been charged with her murder and is due to appear in court today.",
#  "art, photography community, boredpanda have created a thread encouraging parents to showcase their'true nerdy colours'by dressing their babies up as sci - fi characters like princess leia from star wars. one baby is dressed as widely - recognisable nintendo character mario, complete with tiny dungarees, the red flat cap and even a fake felt moustache.",
#  "pacific gas & electric co. to pay record $ 1. 6 billion penalty for unsafe operation of its gas transmission system. most of the penalty amounts to forced spending on improving pipeline safety. pg & e said it has paid more than $ 500 million in claims to victims and victims'families.",
#  'jamal al - labani was visiting his pregnant wife and two - and - a - half - year - old daughter. he was trying to get his family out of the war - torn middle eastern nation. the us has withdrawn its diplomatic staff and the country has shut down most airports. rebels from the houthi islamist group have been battling to take aden.',
#  'dumbarton boss ian murray believes rangers will struggle to maintain pace. the scottish side are currently level on points with hearts at the top of the championship. murray believes a supposedly easier run - in can swing back ahead of the season. hearts face hearts in the last 16 of the scottish championship on sunday.',
#  'robert butler, 43, was transported from bannister house in providence, rhode island to the eleanor slater hospital in cranston on sunday after his nursing home shut down amid financial difficulties. he weighed 900lbs and was trying to find a doctor to perform a gastric bypass and a way to cover the cost of the medical bills. the operation took almost seven hours on sunday and involved the providence and cranton fire departments, lifespan, the hospital association of rhode island and bay crane northeast.',
#  'two teens, 18 and 19, have been charged with attempting to carry out an " isis - inspired " terror plot. the suspects planned to attack during a major national commemoration in a week, police say. " the act that we believe was in preparation involved attacks against police officers, " prime minister tony abbott says.',
#  "malia obama's driving lessons were provided by the secret service. she said it was the armed agents who provided around - the - clock security for the family. the full interview is set to air thursday. the president hasn't driven herself in seven or eight years, she said.",
#  "joelison fernandes da silva, 28, developed gigantism as a child. his rapidly soaring height forced him to drop out of school due to bullying and then refuse to leave the family house for years. but true happiness eventually found him in the form of a 5ft 21 - year - old woman he met online. the brazilian - who has come to be known as'the gentle giant'- married evem medeiros.",
#  "rona fairhead was accused of being either ‘ incredibly naive or totally incompetent ’ by margaret hodge, chairman of the bbc trust, over her handling of a tax evasion scandal at the bank ’ s swiss division. the 53 - year - old has told shareholders she will stay on for'a further one - year period '",
#  "espn sports reporter britt mchenry has been suspended for one week. she was filmed attacking a single mother - of - three at a chinese restaurant. video emerged showing her unleashing verbal attack on a tow clerk. but she resorted to insulting the employee's looks, intelligence and social status. the 28 - year - old has been reinstated as espn sports'sports reporter.",
#  "hartlepool fans are planning to dress up as bob marley for their league two trip to carlisle on saturday 2 may. kick it out have urged carlisle to refuse admission to any fans who might decide to'black up'for the occasion. hartler's fans have a history of fancy dress, travelling as the smurfs to charlton in 2012.",
#  "sheffield wednesday drew 2 - 2 with bournemouth at dean court on saturday. chris maguire opened the scoring for the owls with a late penalty. eddie howe equalised for the visitors with a penalty in stoppage time. but eddie howe was unhappy with the referee's decision to say that callum wilson should be sent off.",
#  "manhattan - based skin laundry says that after just ten minutes, their light and laser procedure will leave your skin'glowing'the new york location is the sixth for skin laundry, which also has clinics in california and arizona. customers sign a waiver that releases their personal information to a funeral director and a coroner.",
#  "mesut ozil says he is now playing his best football since joining the gunners in the summer of 2013. the german midfielder says the injury'worked in my favour'the 26 - year - old says he was exhausted at the start of the season. ozil played every game for the gunners from the beginning of this season. the midfielder says he has come to terms with the premier league.",
#  "gerard t.'the frenchman'ouimette, 75, died sunday in a federal prison in north carolina. ouimet, a former mob enforcer in rhode island with ties to late new england crime boss raymond l. s. patriarca. his uncle was recently diagnosed with lung cancer and died in his sleep at a prison in butner, north carolina, after being diagnosed with a lung cancer in 1996.",
#  "tiger woods played in the tournament for the first time since 2004. he said :'i've been six - under through eight, and just happen to hit two balls in the water on nine'woods said he was in bed watching the par - 3 contest with girlfriend lindsey vonn.",
#  "mike ashley has been accused of making newcastle a'boring'club. the billionaire owner is alarmed at the state of the club. jamie carragher says he's alarmed at what has become of newcastle. fans gathered outside the gallowgate end to chant'we're rich but our team is s * * '",
#  "australian choreographer wade robson, once the singer's staunchest defender, now claims jackson was a predator who repeatedly sexually abused him as a child. robson and another of jackson's alleged victims, james safechuck, are expected to be able to sue for a slice of the late king of pop's $ 1. 5 billion estate. jordan chandler lawsuit alone is alleged to have cost more than $ 40 million to as many as 20 victims.",
#  "president barack obama announced today $ 200 million in additional u. s. humanitarian aid to iraq, but declined to say whether washington would provide additional military support during the meeting.'i think this is why we are having this meeting : to make sure iraqi security forces are in a position to succeed in our common mission,'he told a reporter questioning him about military support following his oval office discussion with iraqi prime minister haidar al - abadi.",
#  'richard eckersley is currently training with la liga side elche. the former manchester united and burnley full - back failed to make an impact in the premier league. the 26 - year - old has been hampered by injuries throughout his career. he made just two premier league appearances for the red devils last season.',
#  'a 32 - year - old man has been charged with torture after a man went to hospital suffering fractures, head injuries and burns. the man, from central queensland, will appear at bundaberg magistrates court on monday. the victim was taken to hospital with burns to 15 per cent of his body. police say the offences took place between march 20 and march 27.',
#  "stuart pearce believes manuel pellegrini deserves more time to turn manchester city around. the 61 - year - old believes city need freshening up drastically this summer. yaya toure has been a rare shining light in manchester city's under performing squad this season. click here for more manchester city news.",
#  "sharon edwards, 55, was last seen between 10pm and 11pm on march 14. her car was left parked in her driveway and her clothes were thrown in the washing basket in her bedroom. her son, eli edwards, said his family is struggling to come to terms with his mother's disappearance. police are treating the investigation as a homicide. ms edwards posted a smiling image of herself in front of a sunrise on the morning she disappeared.",
#  "oratilwe hlongwane, from johannesburg, south africa, plays bass - heavy house music on dj decks. the toddler is already learning to play with his father's dj app on his ipad. his parents were blown away when their son, who still wears nappies, played music from a laptop. the youngster now has nearly 25, 000 facebook fans and sponsorship deals.",
#  "sky's high - octane premier league coverage went head - to - head with arsenal vs reading in the fa cup semi - final on saturday. gary lineker, alan shearer, jason roberts and ian wright fronted the bbc's coverage at wembley. sky have never replaced the disgraced richard keys, who had the benefit of longevity.",
#  'israeli tourist captures the hilarious moment a group of baboons robbed a supply truck of its snacks. the man is forced to retreat as one makes an attempt to scare the baboon away. the monkey appears to taunt the driver before scarpering with more than a handful of snacks from the truck.',
#  "tennessee supreme court postponed execution dates for four men on the state's death row. in 2013 and 2014, the state tried to jump - start the process with a new one - drug lethal injection method and reinstatement of the electric chair as a backup. on friday, the court postponed all executions while the courts decide whether current protocols for putting people to death are constitutional."]

# %%
# !pip install datasets rouge_score sacrebleu
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.19.0)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Collecting sacrebleu
#   Downloading sacrebleu-2.4.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (2023.12.25)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu) (4.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-2.8.2 sacrebleu-2.4.2

# %%
import datasets
from datasets import load_metric

# Load the metrics
rouge = load_metric("rouge")
bleu = load_metric("sacrebleu")

def compute_metrics(predictions, references):
    # Compute ROUGE scores
    rouge_output = rouge.compute(predictions=predictions, references=references)
    # Prepare data for BLEU
    bleu_output = bleu.compute(predictions=[predictions], references=[[references]])

    # Extracting necessary values for display
    rouge_result = {key: value.mid.fmeasure for key, value in rouge_output.items()}  # taking mid Fmeasure value
    bleu_result = bleu_output['score']

    return {
        "rouge": rouge_result,
        "bleu": bleu_result
    }

# Assuming `results` is your dataset with 'pred' as predicted summaries and 'highlights' as references
pred_str = results["pred"]
label_str = results["highlights"]

# Compute metrics
metrics = compute_metrics(pred_str, label_str)
print(metrics)
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for rouge contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/rouge/rouge.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for sacrebleu contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/sacrebleu/sacrebleu.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Downloading builder script:   0%|          | 0.00/2.85k [00:00<?, ?B/s]
# {'rouge': {'rouge1': 0.40074590619989864, 'rouge2': 0.17867402149130923, 'rougeL': 0.26984492668082993, 'rougeLsum': 0.338528944968955}, 'bleu': 14.404937496073263}
